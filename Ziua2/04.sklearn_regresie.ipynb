# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
apartamente = [(37, 65_000), (40, 68_000), (55, 85_000), (60, 90_000),  (80, 130_000), (120, 200_000)]
apartamente = np.array(apartamente)
apartamente
# Out:
# array([[    37,  65000],
#        [    40,  68000],
#        [    55,  85000],
#        [    60,  90000],
#        [    80, 130000],
#        [   120, 200000]])

# %%
suprafete = apartamente[:, 0]
preturi = apartamente[:, 1]
suprafete, preturi
# Out:
# (array([ 37,  40,  55,  60,  80, 120]),
#  array([ 65000,  68000,  85000,  90000, 130000, 200000]))

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
x = suprafete
y = preturi

# %%
x, x.shape
# Out:
# (array([ 37,  40,  55,  60,  80, 120]), (6,))

# %%
reshaped_x = x.reshape((-1, 1))
reshaped_x, reshaped_x.shape
# Out:
# (array([[ 37],
#         [ 40],
#         [ 55],
#         [ 60],
#         [ 80],
#         [120]]),
#  (6, 1))

# %%
model.fit(reshaped_x, y)
# Out:
# LinearRegression()

# %%
valori_deprezis =  [
    [100], [114]
]

model.predict(valori_deprezis)
# Out:
# array([163713.31010453, 186885.99303136])

# %%
model.coef_
# Out:
# array([1655.19163763])

# %%
model.intercept_
# Out:
# np.float64(-1805.853658536551)

# %%
from scipy import stats
rezultat = stats.linregress(x, y)
rezultat
# Out:
# LinregressResult(slope=np.float64(1655.1916376306622), intercept=np.float64(-1805.8536585365946), rvalue=np.float64(0.9951280790065627), pvalue=np.float64(3.554560223096748e-05), stderr=np.float64(81.99262979928592), intercept_stderr=np.float64(5835.7021861211515))

# %%
preturi_optime = model.coef_ * suprafete + model.intercept_

plt.scatter(suprafete, preturi);

plt.plot(suprafete, preturi_optime, c="black");

# %%
preturi_optime_scipy = rezultat.slope * suprafete + rezultat.intercept
plt.plot(suprafete, preturi_optime_scipy, c="red");


preturi_optime_sklearn = model.coef_ * suprafete + model.intercept_ 
plt.plot(suprafete, preturi_optime_sklearn, c="black");

plt.scatter(suprafete, preturi);
