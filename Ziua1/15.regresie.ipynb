# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([3, 4, 5, 6, 7, 8])
y = np.array([3, 5, 6, 6, 8, 8])
plt.scatter(x, y)

# %%
x = np.array([3, 4, 5, 6, 7, 8])
y = np.array([3, 5, 6, 6, 8, 8])
plt.scatter(x, y)
plt.plot(x, y);

# %%
x = np.array([3, 4, 5, 6, 7, 8])
y =  x
plt.scatter(x, y)
plt.plot(x, y);

# %%
x = np.array([3, 4, 5, 6, 7, 8])
y = np.array([3, 3, 6, 6, 8, 8])

y_liniar = x

plt.scatter(x, y)
plt.plot(x, y);
plt.plot(x, y_liniar);
