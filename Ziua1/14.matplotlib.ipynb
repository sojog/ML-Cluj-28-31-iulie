# %% [markdown]
# # pip install matplotlib

# %% [markdown]
# # mat -> matlab
# # plot -> grafic
# # lib -> librarie

# %%
import matplotlib.pyplot as plt

# %%
x = [ 10]
y = [ 12]
plt.scatter(x, y);

# %%
x = [ 10]
y = [ 12]
plt.scatter(x, y);
plt.show();

# %%
x = [ 10, 8]
y = [ 12, 9]
plt.scatter(x, y);

# %%
x = [ 10, 8]
y = [ 12, 9]
plt.plot(x, y);

# %%
x = [ 10, 8, 7]
y = [ 12, 9, 7]
plt.plot(x, y);

# %%
x = [ 10, 8, 7, 15]
y = [ 12, 9, 7, 20]
plt.plot(x, y);

# %%
x = [ 10, 8, 7]
y = [ 12, 9, 7]
plt.bar(x, y);

# %%
x = [ 10, 8, 7]
y = [ 12, 9, 7]
plt.scatter(x, y);
plt.plot(x, y);

# %%
import numpy as np

# %%
x = np.array([ 10, 8, 7])
y = np.array([ 12, 9, 7])
plt.scatter(x, y);
plt.plot(x, y);

# %%
x = np.arange(10, 15)
y = x  * 2
plt.scatter(x, y);
plt.plot(x, y);

# %%
x = np.arange(10, 15)
y = x  * 2 + 5
plt.scatter(x, y);
plt.plot(x, y);

# %%
x, y
# Out:
# (array([10, 11, 12, 13, 14]), array([25, 27, 29, 31, 33]))
