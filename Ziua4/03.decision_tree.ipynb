# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("date_categorice.csv")
df
# Out:
#         coord_x     coord_y category
# 0     89.445454  400.737206        a
# 1    119.228069  441.574349        a
# 2    126.619690  484.234269        a
# 3    102.048652  428.618483        a
# 4    113.215882  462.686939        a
# ..          ...         ...      ...
# 689  625.495686   36.064532        d
# 690  596.454935   76.528652        d
# 691  625.536933   91.336058        d
# 692  641.918581   93.482770        d
# 693  602.609569   70.600203        d
#
# [694 rows x 3 columns]

# %%
plt.scatter(df["coord_x"], df["coord_y"]);

# %%
colors = {
    'a':'black', 'b':'blue', 'c':'red', 'd':'yellow'
}

# %%
plt.scatter(df["coord_x"], df["coord_y"], c=df['category'].map(colors));

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()
model
# Out:
# DecisionTreeClassifier()

# %%
model.fit(df[["coord_x", "coord_y"]], df['category'])
# Out:
# DecisionTreeClassifier()

# %%
import graphviz
from sklearn.tree import export_graphviz

# %%
exported_data = export_graphviz(model, feature_names=["coord_x", "coord_y"], class_names=["black", "blue", "red", "yellow"])
exported_graph = graphviz.Source(exported_data)
exported_graph.render("Categorii de culori", format="png")
exported_graph.view()
# Out:
# 'Categorii de culori.pdf'

# %%
plt.scatter(df["coord_x"], df["coord_y"], c=df['category'].map(colors));
plt.plot(np.arange(800), np.ones(800) * 245);

# %%
plt.scatter(df["coord_x"], df["coord_y"], c=df['category'].map(colors));
plt.plot(np.arange(800), np.ones(800) * 245);

plt.plot(np.ones(800) * 340, np.arange(800));

# %%
plt.scatter(df["coord_x"], df["coord_y"], c=df['category'].map(colors));
plt.plot(np.arange(800), np.ones(800) * 245);

plt.plot(np.ones(245) * 340, np.arange(245));

# %%
plt.scatter(df["coord_x"], df["coord_y"], c=df['category'].map(colors));
plt.plot(np.arange(800), np.ones(800) * 245);

plt.plot(np.ones(245) * 340, np.arange(245));
plt.plot(np.ones(600- 245) * 328, np.arange(245, 600));
