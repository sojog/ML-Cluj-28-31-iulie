# %% [markdown]
# # pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("boston_data.csv", index_col="ID") # coloana index este setata la ID
df
# Out:
#      indus  chas    nox     rm   age     dis  rad  tax  ptratio  lstat  medv
# ID
# 1     2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3   4.98  24.0
# 2     7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8   9.14  21.6
# 4     2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7   2.94  33.4
# 5     2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7   5.33  36.2
# 7     7.87     0  0.524  6.012  66.6  5.5605    5  311     15.2  12.43  22.9
# ..     ...   ...    ...    ...   ...     ...  ...  ...      ...    ...   ...
# 500   9.69     0  0.585  5.569  73.5  2.3999    6  391     19.2  15.10  17.5
# 502  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0   9.67  22.4
# 503  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0   9.08  20.6
# 504  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0   5.64  23.9
# 506  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0   7.88  11.9
#
# [333 rows x 11 columns]

# %%
df.describe()
# Out:
#             indus        chas         nox          rm         age         dis  \
# count  333.000000  333.000000  333.000000  333.000000  333.000000  333.000000
# mean    11.293483    0.060060    0.557144    6.265619   68.226426    3.709934
# std      6.998123    0.237956    0.114955    0.703952   28.133344    1.981123
# min      0.740000    0.000000    0.385000    3.561000    6.000000    1.129600
# 25%      5.130000    0.000000    0.453000    5.884000   45.400000    2.122400
# 50%      9.900000    0.000000    0.538000    6.202000   76.700000    3.092300
# 75%     18.100000    0.000000    0.631000    6.595000   93.800000    5.116700
# max     27.740000    1.000000    0.871000    8.725000  100.000000   10.710300
#
#               rad         tax     ptratio       lstat        medv
# count  333.000000  333.000000  333.000000  333.000000  333.000000
# mean     9.633634  409.279279   18.448048   12.515435   22.768769
# std      8.742174  170.841988    2.151821    7.067781    9.173468
# ...

# %%
df.head()
# Out:
#     indus  chas    nox     rm   age     dis  rad  tax  ptratio  lstat  medv
# ID
# 1    2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3   4.98  24.0
# 2    7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8   9.14  21.6
# 4    2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7   2.94  33.4
# 5    2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7   5.33  36.2
# 7    7.87     0  0.524  6.012  66.6  5.5605    5  311     15.2  12.43  22.9

# %%
df.tail()
# Out:
#      indus  chas    nox     rm   age     dis  rad  tax  ptratio  lstat  medv
# ID
# 500   9.69     0  0.585  5.569  73.5  2.3999    6  391     19.2  15.10  17.5
# 502  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0   9.67  22.4
# 503  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0   9.08  20.6
# 504  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0   5.64  23.9
# 506  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0   7.88  11.9

# %%
df [  ["indus", "chas"]   ]
# Out:
#      indus  chas
# ID
# 1     2.31     0
# 2     7.07     0
# 4     2.18     0
# 5     2.18     0
# 7     7.87     0
# ..     ...   ...
# 500   9.69     0
# 502  11.93     0
# 503  11.93     0
# 504  11.93     0
# 506  11.93     0
#
# [333 rows x 2 columns]

# %% [markdown]
# # TARGET VALUES

# %%
y  = df["medv"]  # # cu 1 paranteza -> Serie (array unidimensional)
type(y )
# Out:
# pandas.core.series.Series

# %%
y  = df [["medv"]]   # cu 2 paranteze -> DataFrame (matrice)
type(y )
# Out:
# pandas.core.frame.DataFrame

# %%
y.head(2)
# Out:
#     medv
# ID
# 1   24.0
# 2   21.6

# %% [markdown]
# # DATA -> features

# %%
x = df.drop("medv", axis=1)
x
# Out:
#      indus  chas    nox     rm   age     dis  rad  tax  ptratio  lstat
# ID
# 1     2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3   4.98
# 2     7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8   9.14
# 4     2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7   2.94
# 5     2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7   5.33
# 7     7.87     0  0.524  6.012  66.6  5.5605    5  311     15.2  12.43
# ..     ...   ...    ...    ...   ...     ...  ...  ...      ...    ...
# 500   9.69     0  0.585  5.569  73.5  2.3999    6  391     19.2  15.10
# 502  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0   9.67
# 503  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0   9.08
# 504  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0   5.64
# 506  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0   7.88
#
# [333 rows x 10 columns]

# %%
x.shape, y.shape
# Out:
# ((333, 10), (333, 1))

# %%
from sklearn.linear_model import LinearRegression

# %%
import numpy as np

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=8989)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((266, 10), (67, 10), (266, 1), (67, 1))

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(x_test, y_test)
# Out:
# 0.7473432385464851

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn_model = KNeighborsRegressor(n_neighbors=4)
knn_model
# Out:
# KNeighborsRegressor(n_neighbors=4)

# %%
knn_model.fit(x_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=4)

# %%
knn_model.score(x_test, y_test)
# Out:
# 0.6580621736924274

# %%
linear_y_predict = model.predict(x_test)
knn_y_predict = knn_model.predict(x_test)

# %%
type(linear_y_predict), type(y_test), linear_y_predict.shape
# Out:
# (numpy.ndarray, pandas.core.frame.DataFrame, (67, 1))

# %%
linear_y_predict = linear_y_predict.flatten()
knn_y_predict = knn_y_predict.flatten()
real_y = np.array(y_test).flatten()

# %%
pd.DataFrame({"real": real_y,
              "linear":linear_y_predict, 
              "knn":knn_y_predict})
# Out:
#     real     linear     knn
# 0   24.4  23.634975  24.650
# 1   19.3  16.489814  19.800
# 2   23.5  28.432652  24.850
# 3   21.2  23.796341  20.150
# 4   31.1  30.501534  29.275
# ..   ...        ...     ...
# 62  16.3  15.196702  10.200
# 63   8.7  11.300972  11.400
# 64  15.2  19.080116  16.075
# 65  22.0  26.246796  21.025
# 66  29.4  31.379470  21.625
#
# [67 rows x 3 columns]

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_model = GridSearchCV(KNeighborsRegressor(), {"n_neighbors": range(2, 11)})
grid_model
# Out:
# GridSearchCV(estimator=KNeighborsRegressor(),
#              param_grid={'n_neighbors': range(2, 11)})

# %%
grid_model.fit(x_train, y_train)
# Out:
# GridSearchCV(estimator=KNeighborsRegressor(),
#              param_grid={'n_neighbors': range(2, 11)})

# %%
grid_model.best_estimator_
# Out:
# KNeighborsRegressor(n_neighbors=4)

# %%
grid_model.best_score_
# Out:
# np.float64(0.574633334353033)

# %%
x_train["indus"].min(), x_train["indus"].max(),
# Out:
# (np.float64(0.74), np.float64(27.74))

# %%
x_train["age"].min(), x_train["age"].max(),
# Out:
# (np.float64(6.0), np.float64(100.0))

# %%
x_train
# Out:
#      indus  chas    nox     rm    age     dis  rad  tax  ptratio  lstat
# ID
# 184   2.46     0  0.488  6.563   95.6  2.8470    3  193     17.8   5.68
# 307   2.18     0  0.472  7.420   71.9  3.0992    7  222     18.4   6.47
# 31    8.14     0  0.538  5.713   94.1  4.2330    4  307     21.0  22.60
# 416  18.10     0  0.679  6.434  100.0  1.8347   24  666     20.2  29.05
# 252   5.86     0  0.431  6.438    8.9  7.3967    7  330     19.1   3.59
# ..     ...   ...    ...    ...    ...     ...  ...  ...      ...    ...
# 223   6.20     1  0.507  6.879   77.7  3.2721    8  307     17.4   9.93
# 368  18.10     0  0.631  3.863  100.0  1.5106   24  666     20.2  13.33
# 19    8.14     0  0.538  5.456   36.6  3.7965    4  307     21.0  11.69
# 2     7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8   9.14
# 135  21.89     0  0.624  5.757   98.4  2.3460    4  437     21.2  17.31
#
# [266 rows x 10 columns]
