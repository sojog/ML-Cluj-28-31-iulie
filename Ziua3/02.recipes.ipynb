# %%
import pandas as pd

# %%
df = pd.read_csv("Datasets/recipes.csv")
df.head(2)
# Out:
#    Unnamed: 0                      name  prepTimeMinutes  cookTimeMinutes  \
# 0           0  Classic Margherita Pizza               20               15
# 1           1       Vegetarian Stir-Fry               15               20
#
#    servings  caloriesPerServing  reviewCount
# 0         4                 300           98
# 1         3                 250           26

# %%
df = pd.read_csv("Datasets/recipes.csv", index_col=0)
df.head(2)
# Out:
#                        name  prepTimeMinutes  cookTimeMinutes  servings  \
# 0  Classic Margherita Pizza               20               15         4
# 1       Vegetarian Stir-Fry               15               20         3
#
#    caloriesPerServing  reviewCount
# 0                 300           98
# 1                 250           26

# %%
df.count()
# Out:
# name                  30
# prepTimeMinutes       30
# cookTimeMinutes       30
# servings              30
# caloriesPerServing    30
# reviewCount           30
# dtype: int64

# %%
df.dtypes
# Out:
# name                  object
# prepTimeMinutes        int64
# cookTimeMinutes        int64
# servings               int64
# caloriesPerServing     int64
# reviewCount            int64
# dtype: object

# %%
df["cookTimeMinutes"].min(), df["cookTimeMinutes"].max()
# Out:
# (np.int64(0), np.int64(45))

# %%
df[df["cookTimeMinutes"] < 30].count()
# Out:
# name                  22
# prepTimeMinutes       22
# cookTimeMinutes       22
# servings              22
# caloriesPerServing    22
# reviewCount           22
# dtype: int64

# %%
df[ (df["cookTimeMinutes"] > 20) & (df["cookTimeMinutes"] < 30)]
# Out:
#                               name  prepTimeMinutes  cookTimeMinutes  \
# 4              Mango Salsa Chicken               15               25
# 15             Japanese Ramen Soup               20               25
# 19  Butter Chicken (Murgh Makhani)               30               25
#
#     servings  caloriesPerServing  reviewCount
# 4          3                 380           63
# 15         2                 480           38
# 19         4                 480           44

# %%
df[ (df["cookTimeMinutes"] >= 20) & (df["cookTimeMinutes"] <= 30)]
# Out:
#                                  name  prepTimeMinutes  cookTimeMinutes  \
# 1                 Vegetarian Stir-Fry               15               20
# 3               Chicken Alfredo Pasta               15               20
# 4                 Mango Salsa Chicken               15               25
# 9                 Shrimp Scampi Pasta               15               20
# 11                     Chicken Karahi               20               30
# 13                      Chapli Kebabs               30               20
# 14  Saag (Spinach) with Makki di Roti               40               30
# 15                Japanese Ramen Soup               20               25
# 16           Moroccan Chickpea Tagine               15               30
# 17                    Korean Bibimbap               30               20
# 19     Butter Chicken (Murgh Makhani)               30               25
# 20                   Thai Green Curry               20               30
# ...

# %%
import numpy as np

# %%
np.array(df["caloriesPerServing"].sort_values())
# Out:
# array([120, 150, 150, 180, 180, 200, 220, 220, 250, 280, 280, 280, 300,
#        320, 320, 320, 350, 380, 380, 380, 400, 400, 420, 420, 480, 480,
#        480, 500, 550, 550])

# %%
df[df["caloriesPerServing"] == df["caloriesPerServing"].min()]
# Out:
#                       name  prepTimeMinutes  cookTimeMinutes  servings  \
# 6  Tomato Basil Bruschetta               15               10         6
#
#    caloriesPerServing  reviewCount
# 6                 120           95

# %%
df[df["caloriesPerServing"] == df["caloriesPerServing"].max()]
# Out:
#                name  prepTimeMinutes  cookTimeMinutes  servings  \
# 10  Chicken Biryani               30               45         6
# 17  Korean Bibimbap               30               20         2
#
#     caloriesPerServing  reviewCount
# 10                 550           32
# 17                 550           56

# %%
df["servings"].unique()
# Out:
# array([ 4,  3, 24,  6,  2,  5,  1])

# %%
df.groupby("servings").agg(['count'])
# Out:
#           name prepTimeMinutes cookTimeMinutes caloriesPerServing reviewCount
#          count           count           count              count       count
# servings
# 1            2               2               2                  2           2
# 2            5               5               5                  5           5
# 3            4               4               4                  4           4
# 4           12              12              12                 12          12
# 5            1               1               1                  1           1
# 6            5               5               5                  5           5
# 24           1               1               1                  1           1

# %%
df.groupby("servings").agg(['count'])["name"]
# Out:
#           count
# servings
# 1             2
# 2             5
# 3             4
# 4            12
# 5             1
# 6             5
# 24            1

# %%
df[df["servings"] == 6]
# Out:
#                        name  prepTimeMinutes  cookTimeMinutes  servings  \
# 6   Tomato Basil Bruschetta               15               10         6
# 10          Chicken Biryani               30               45         6
# 18           Greek Moussaka               45               45         6
# 22         Italian Tiramisu               30                0         6
# 26          Russian Borscht               30               40         6
#
#     caloriesPerServing  reviewCount
# 6                  120           95
# 10                 550           32
# 18                 420           26
# 22                 350            0
# 26                 220           39

# %%
df.head(1)
# Out:
#                        name  prepTimeMinutes  cookTimeMinutes  servings  \
# 0  Classic Margherita Pizza               20               15         4
#
#    caloriesPerServing  reviewCount
# 0                 300           98

# %%
retete_noi = {
    'name':['Ciorba'],
    'prepTimeMinutes' : [60],
    'cookTimeMinutes':[120],
    'servings':[8],
    'caloriesPerServing' : [450],
    'reviewCount':[2]
}
new_data_df = pd.DataFrame(retete_noi)
new_data_df
# Out:
#      name  prepTimeMinutes  cookTimeMinutes  servings  caloriesPerServing  \
# 0  Ciorba               60              120         8                 450
#
#    reviewCount
# 0            2

# %%
merged_df = pd.concat([new_data_df, df])
merged_df = merged_df.reset_index(drop=True)
merged_df.head(4)
# Out:
#                        name  prepTimeMinutes  cookTimeMinutes  servings  \
# 0                    Ciorba               60              120         8
# 1  Classic Margherita Pizza               20               15         4
# 2       Vegetarian Stir-Fry               15               20         3
# 3    Chocolate Chip Cookies               15               10        24
#
#    caloriesPerServing  reviewCount
# 0                 450            2
# 1                 300           98
# 2                 250           26
# 3                 150           13

# %%
merged_df[["prepTimeMinutes","cookTimeMinutes"]].head()
# Out:
#    prepTimeMinutes  cookTimeMinutes
# 0               60              120
# 1               20               15
# 2               15               20
# 3               15               10
# 4               15               20

# %%
merged_df.rename(columns={"prepTimeMinutes":"prepTime"}).head(2)
# Out:
#                        name  prepTime  cookTimeMinutes  servings  \
# 0                    Ciorba        60              120         8
# 1  Classic Margherita Pizza        20               15         4
#
#    caloriesPerServing  reviewCount
# 0                 450            2
# 1                 300           98

# %%
merged_df["light"] = merged_df["caloriesPerServing"] < 300
merged_df
# Out:
#                                  name  prepTimeMinutes  cookTimeMinutes  \
# 0                              Ciorba               60              120
# 1            Classic Margherita Pizza               20               15
# 2                 Vegetarian Stir-Fry               15               20
# 3              Chocolate Chip Cookies               15               10
# 4               Chicken Alfredo Pasta               15               20
# 5                 Mango Salsa Chicken               15               25
# 6           Quinoa Salad with Avocado               20               15
# 7             Tomato Basil Bruschetta               15               10
# 8          Beef and Broccoli Stir-Fry               20               15
# 9                       Caprese Salad               10                0
# 10                Shrimp Scampi Pasta               15               20
# 11                    Chicken Biryani               30               45
# ...
