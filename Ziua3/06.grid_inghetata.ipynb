# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsRegressor

# %%
df = pd.read_csv("Datasets/date_inghetata.csv")
df.head(2)
# Out:
#    temperatura  vanzari      luna zi_saptamana
# 0            8       25  ianuarie         luni
# 1           10       35  ianuarie        marti

# %%
data = df[["temperatura"]] # x
data.head(2)
# Out:
#    temperatura
# 0            8
# 1           10

# %%
target = df[["vanzari"]]
target.head(2)
# Out:
#    vanzari
# 0       25
# 1       35

# %%
from sklearn.model_selection import train_test_split

# %%
train_data, test_data, train_target, test_target = train_test_split(data, target, test_size=0.22)

# %%
model = KNeighborsRegressor()
model.fit(train_data, train_target)
model.score(test_data, test_target)
# Out:
# 0.990701798353269

# %%
model = KNeighborsRegressor(n_neighbors=4)
model.fit(train_data, train_target)
model.score(test_data, test_target)
# Out:
# 0.9909407938654552

# %%
model = KNeighborsRegressor(n_neighbors=6)
model.fit(train_data, train_target)
model.score(test_data, test_target)
# Out:
# 0.9906607074029522

# %%
list(range(2, 11))
# Out:
# [2, 3, 4, 5, 6, 7, 8, 9, 10]

# %%
d = {

}

for k in range(2, 11):
    model = KNeighborsRegressor(n_neighbors=k)
    model.fit(train_data, train_target)
    k_score = model.score(test_data, test_target)
    d[k] = k_score

print(d)
# Out:
# {2: 0.9879310467117908, 3: 0.9891316010314106, 4: 0.9909407938654552, 5: 0.990701798353269, 6: 0.9906607074029522, 7: 0.9901709199580435, 8: 0.988714554823634, 9: 0.9892696201338301, 10: 0.9899509381152909}

# %%
d.items()
# Out:
# dict_items([(2, 0.9879310467117908), (3, 0.9891316010314106), (4, 0.9909407938654552), (5, 0.990701798353269), (6, 0.9906607074029522), (7, 0.9901709199580435), (8, 0.988714554823634), (9, 0.9892696201338301), (10, 0.9899509381152909)])

# %%
pd.DataFrame(d.items()).sort_values(1, ascending=False)
# Out:
#     0         1
# 2   4  0.990941
# 3   5  0.990702
# 4   6  0.990661
# 5   7  0.990171
# 8  10  0.989951
# 7   9  0.989270
# 1   3  0.989132
# 6   8  0.988715
# 0   2  0.987931

# %%
from sklearn.model_selection import GridSearchCV

# %%
estimator = KNeighborsRegressor()

# %%
wrapped_model = GridSearchCV(estimator, param_grid={
    "n_neighbors":list(range(2, 11))
})
wrapped_model
# Out:
# GridSearchCV(estimator=KNeighborsRegressor(),
#              param_grid={'n_neighbors': [2, 3, 4, 5, 6, 7, 8, 9, 10]})

# %%
wrapped_model.fit(train_data, train_target)
wrapped_model
# Out:
# GridSearchCV(estimator=KNeighborsRegressor(),
#              param_grid={'n_neighbors': [2, 3, 4, 5, 6, 7, 8, 9, 10]})

# %%
wrapped_model.best_estimator_
# Out:
# KNeighborsRegressor(n_neighbors=6)

# %%
wrapped_model.score
# Out:
# <bound method BaseSearchCV.score of GridSearchCV(estimator=KNeighborsRegressor(),
#              param_grid={'n_neighbors': [2, 3, 4, 5, 6, 7, 8, 9, 10]})>
